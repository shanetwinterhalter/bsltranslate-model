# %% [markdown]
# # Imports

# %%
# Allow importing items in src folder
import sys

SCRIPT_DIR = "/home/shane/Projects/sign_data"
sys.path.append(SCRIPT_DIR)

# %%
import pandas as pd
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
from torch.utils.mobile_optimizer import optimize_for_mobile
from datetime import datetime
from os import listdir, mkdir

# %%
from src.files import read_from_file, load_pickle, save_pickle, save_csv
from src.data_proc import normalize_data, tokenize
from src.training import split_by_video, to_device, DeviceDataLoader, get_optimizer, set_learning_rates, \
                         train_model, valid_model, calc_class_weights
from src.datasets import *
from src.models import *
from src.utilities import lr_finder

# %% [markdown]
# # Variables

# %%
run_lr_finder = False
train = True
print_per_sign_stats = True
save = True

# %%
data_folder = '../video_data'
vocab_file = "../vocab.csv"

# %%
model_name = 'cnn_3d'
fps = 7
in_chan = 1
validation_pct = 0.15
batch_size = 16384
learning_rate = 1e-2
weight_decay = 0
epochs = 25
no_of_coords = 126
dims = 3

# %%
model_fn = Cnn_3d
dataset_fn = DatasetStream3d
loss_func = nn.CrossEntropyLoss

# %%
model_output_folder = "../models"

# %%
lr_finder_weight_decays = [0, 1e-4, 1e-3, 1e-2, 1e-1]

# %% [markdown]
# # Load Mediapipe data - Individual videos

# %%
file_list = listdir(data_folder)
data = []
metadata = []
for file in file_list:
   data_import = load_pickle(data_folder + "/" + file)
   data.append(pd.DataFrame(data_import[0]))
   metadata.append(pd.DataFrame(data_import[1]))
data_df = pd.concat(data)
metadata_df = pd.concat(metadata)

# %% [markdown]
# # Normalize Data

# %%
normalized_data_df, normalization_stats = normalize_data(data_df)

# %% [markdown]
# # Tokenise Labels

# %%
vocab = read_from_file(vocab_file)
no_lbls = len(vocab)

# %%
metadata_df['label'] = [tokenize(label, vocab) for label in metadata_df['label']]

# %% [markdown]
# # Create Training & Validation Set

# %%
train_df, valid_df = split_by_video(pd.concat([normalized_data_df, metadata_df], axis=1), validation_pct, seed_no=0.05)

# %%
train_df['vid_fname'].unique()
# Out:
# array(['../videos/Alphabet36.mp4', '../videos/Alphabet41.mp4',
#        '../videos/Alphabet38.mp4', '../videos/Alphabet31.mp4',
#        '../videos/Alphabet16.mp4', '../videos/Alphabet07.webm',
#        '../videos/Alphabet35.mp4', '../videos/Alphabet08.mp4',
#        '../videos/Alphabet23.mp4', '../videos/Alphabet15.mp4',
#        '../videos/Alphabet28.mp4', '../videos/Alphabet32.mp4',
#        '../videos/Alphabet34.mp4', '../videos/Alphabet49.mp4',
#        '../videos/Alphabet29.mp4', '../videos/Alphabet14.mp4',
#        '../videos/Alphabet50.mp4', '../videos/Alphabet43.mp4',
#        '../videos/Alphabet44.mp4', '../videos/Alphabet06.webm',
#        '../videos/Alphabet03.mp4', '../videos/Alphabet33.mp4',
#        '../videos/Alphabet12.mp4', '../videos/Alphabet19.mp4',
#        '../videos/Alphabet27.mp4', '../videos/Alphabet30.mp4',
#        '../videos/Alphabet09.mp4', '../videos/Alphabet02.mp4',
#        '../videos/Alphabet11.mp4', '../videos/Alphabet48.mp4',
#        '../videos/Alphabet05.mp4', '../videos/Alphabet13.mp4',
#        '../videos/Alphabet47.mp4', '../videos/Alphabet04.mp4',
#        '../videos/Alphabet21.mp4', '../videos/Alphabet10.mp4',
#        '../videos/Alphabet18.mp4', '../videos/Alphabet25.mp4',
#        '../videos/Alphabet22.mp4', '../videos/Alphabet17.mp4',
#        '../videos/Alphabet40.mp4'], dtype=object)

# %%
valid_df['vid_fname'].unique()
# Out:
# array(['../videos/Alphabet24.mp4', '../videos/Alphabet39.mp4',
#        '../videos/Alphabet46.mp4', '../videos/Alphabet37.mp4',
#        '../videos/Alphabet20.mp4', '../videos/Alphabet01.mp4',
#        '../videos/Alphabet26.mp4'], dtype=object)

# %% [markdown]
# # Create Dataset

# %%
train_ds = dataset_fn(train_df, normalization_stats, frames_per_sign=fps)
valid_ds = dataset_fn(valid_df, normalization_stats, frames_per_sign=fps)

# %% [markdown]
# # Create Dataloaders

# %%
train_dl = DeviceDataLoader(DataLoader(train_ds, batch_size=batch_size, shuffle=False))
valid_dl = DeviceDataLoader(DataLoader(valid_ds, batch_size=batch_size, shuffle=False))

# %% [markdown]
# # Calculate Class Weights

# %% [markdown]
# Hopefully this will take care of how NaS has many times more examples in the dataset than the other signs

# %%
class_weights = calc_class_weights(train_df, no_lbls)
class_weights.size()
# Out:
# torch.Size([27])

# %% [markdown]
# # Run Learning Rate Finder (Optional)

# %%
if run_lr_finder:
    loss_fn = loss_func(weight=class_weights.cuda())
    model = model_fn(no_lbls, in_channels=in_chan)
    to_device(model)
    for wd in lr_finder_weight_decays:
        lrs, losses = lr_finder(train_dl, model, loss_fn, weight_decay=wd)
        plt.plot(lrs, losses)
        plt.xlabel('Learning Rates (10^)')
        plt.ylabel('Loss')
        plt.title("Weight Decay: {}".format(wd))
        plt.show()

# %% [markdown]
# # Create Model

# %%
if train:
    model = model_fn(no_lbls, in_channels=in_chan)
    to_device(model)
    optim = get_optimizer(model, lr=learning_rate, wd=weight_decay)
    loss_fn = loss_func(weight=class_weights.cuda())

# %% [markdown]
# # Train

# %%
if train:
    lrs = set_learning_rates(epochs * len(train_dl), learning_rate)
    for epoch in range(epochs):
        print("Epoch: ", epoch)
        loss = train_model(model, optim, loss_fn, train_dl, lrs, epoch)
        print("Training Loss: ", loss)
        valid_loss, acc, sign_correct = valid_model(model, valid_dl, loss_fn, no_lbls)
        print("Validation Loss: ", valid_loss)
        print("Accuracy: ", acc)
        if print_per_sign_stats:
            print("Per sign accuracy:")
            for i, j in zip(vocab, sign_correct):
                print("{}: {}".format(vocab[i], j))
# Out:
# Epoch:  0
# Training Loss:  2.6243132659675137
# Validation Loss:  3.020409215004247
# Accuracy:  0.04995274740110706
# Per sign accuracy:
# ['NaS']: 0.9627870737951248
# ['a']: 0.0
# ['b']: 0.0
# ['c']: 0.040382571732199786
# ['d']: 0.0
# ['e']: 0.0
# ['f']: 0.039663461538461536
# ['g']: 0.3218274111675127
# ['h']: 0.02092675635276532
# ['i']: 0.0
# ['j']: 0.0
# ['k']: 0.14731369150779897
# ['l']: 0.011922503725782414
# ['m']: 0.1614457831325301
# ['n']: 0.0
# ['o']: 0.0
# ['p']: 0.0
# ['q']: 0.07535121328224777
# ['r']: 0.0
# ['s']: 0.20237087214225233
# ['t']: 0.0
# ['y']: 0.0
# ['u']: 0.0
# ['v']: 0.23502994011976047
# ['w']: 0.0
# ['x']: 0.0
# ['z']: 0.03812316715542522
# Epoch:  1
# Training Loss:  1.8425425300223883
# Validation Loss:  2.2904642513159326
# Accuracy:  0.3242878358309707
# Per sign accuracy:
# ['NaS']: 0.585426483137313
# ['a']: 0.7554945054945055
# ['b']: 0.9196428571428571
# ['c']: 0.8618490967056323
# ['d']: 0.29545454545454547
# ['e']: 0.0
# ['f']: 0.6850961538461539
# ['g']: 0.7472081218274111
# ['h']: 0.05082212257100149
# ['i']: 0.09111361079865017
# ['j']: 0.125
# ['k']: 0.01386481802426343
# ['l']: 0.010432190760059613
# ['m']: 0.0
# ['n']: 0.40890269151138714
# ['o']: 0.00331858407079646
# ['p']: 0.24356223175965666
# ['q']: 0.12643678160919541
# ['r']: 0.0
# ['s']: 0.7188823031329382
# ['t']: 0.3483043079743355
# ['y']: 0.0035885167464114833
# ['u']: 0.0
# ['v']: 0.0014970059880239522
# ['w']: 0.21544715447154472
# ['x']: 0.5906801007556675
# ['z']: 0.7052785923753666
# Epoch:  2
# Training Loss:  1.503106725993106
# Validation Loss:  2.3148224861061277
# Accuracy:  0.32406282345529
# Per sign accuracy:
# ['NaS']: 0.53307609542537
# ['a']: 0.004578754578754579
# ['b']: 0.5433673469387755
# ['c']: 0.7417640807651434
# ['d']: 0.4090909090909091
# ['e']: 0.0
# ['f']: 0.7259615384615384
# ['g']: 0.04060913705583756
# ['h']: 0.31988041853512705
# ['i']: 0.515185601799775
# ['j']: 0.33125
# ['k']: 0.21663778162911612
# ['l']: 0.3561847988077496
# ['m']: 0.28313253012048195
# ['n']: 0.5859213250517599
# ['o']: 0.00995575221238938
# ['p']: 0.5997854077253219
# ['q']: 0.09067688378033206
# ['r']: 0.002328288707799767
# ['s']: 0.9602032176121931
# ['t']: 0.31072410632447295
# ['y']: 0.005980861244019139
# ['u']: 0.0
# ['v']: 0.004491017964071856
# ['w']: 0.017615176151761516
# ['x']: 0.2783375314861461
# ['z']: 0.9208211143695014
# Epoch:  3
# Training Loss:  1.3320408222504794
# Validation Loss:  2.148293354669612
# Accuracy:  0.3843211376625714
# Per sign accuracy:
# ['NaS']: 0.5458019515452825
# ['a']: 0.3131868131868132
# ['b']: 0.7755102040816326
# ['c']: 0.7948990435706695
# ['d']: 0.01076555023923445
# ['e']: 0.01056338028169014
# ['f']: 0.8112980769230769
# ['g']: 0.15634517766497463
# ['h']: 0.21674140508221226
# ['i']: 0.19122609673790777
# ['j']: 0.62875
# ['k']: 0.010398613518197574
# ['l']: 0.08494783904619971
# ['m']: 0.7433734939759036
# ['n']: 0.4648033126293996
# ['o']: 0.04314159292035398
# ['p']: 0.7135193133047211
# ['q']: 0.38697318007662834
# ['r']: 0.0
# ['s']: 0.8611346316680779
# ['t']: 0.28780934922089824
# ['y']: 0.39593301435406697
# ['u']: 0.0
# ['v']: 0.3008982035928144
# ['w']: 0.6626016260162602
# ['x']: 0.3136020151133501
# ['z']: 0.6451612903225806
# Epoch:  4
# Training Loss:  1.2221729695532872
# Validation Loss:  4.653767928090194
# Accuracy:  0.24188830385671212
# Per sign accuracy:
# ['NaS']: 0.48974140169925423
# ['a']: 0.0027472527472527475
# ['b']: 0.7895408163265306
# ['c']: 0.9277364505844846
# ['d']: 0.0
# ['e']: 0.0
# ['f']: 0.25961538461538464
# ['g']: 0.0
# ['h']: 0.06576980568011959
# ['i']: 0.0
# ['j']: 0.0075
# ['k']: 0.0
# ['l']: 0.21013412816691504
# ['m']: 0.2289156626506024
# ['n']: 0.6656314699792961
# ['o']: 0.20353982300884957
# ['p']: 0.1555793991416309
# ['q']: 0.3767560664112388
# ['r']: 0.0011641443538998836
# ['s']: 0.9754445385266723
# ['t']: 0.2648945921173236
# ['y']: 0.16028708133971292
# ['u']: 0.0
# ['v']: 0.0
# ['w']: 0.0
# ['x']: 0.0
# ['z']: 0.6451612903225806
# Epoch:  5
# Training Loss:  1.1350950637188384
# Validation Loss:  3.690994725205247
# Accuracy:  0.29706133837361054
# Per sign accuracy:
# ['NaS']: 0.5097391756019738
# ['a']: 0.027472527472527472
# ['b']: 0.012755102040816327
# ['c']: 0.9341126461211477
# ['d']: 0.16028708133971292
# ['e']: 0.007042253521126761
# ['f']: 0.9158653846153846
# ['g']: 0.21725888324873097
# ['h']: 0.47234678624813153
# ['i']: 0.3093363329583802
# ['j']: 0.02625
# ['k']: 0.3188908145580589
# ['l']: 0.14307004470938897
# ['m']: 0.0
# ['n']: 0.593167701863354
# ['o']: 0.21460176991150443
# ['p']: 0.3669527896995708
# ['q']: 0.46360153256704983
# ['r']: 0.006984866123399301
# ['s']: 0.9974597798475868
# ['t']: 0.00458295142071494
# ['y']: 0.46172248803827753
# ['u']: 0.001943634596695821
# ['v']: 0.004491017964071856
# ['w']: 0.02710027100271003
# ['x']: 0.44836272040302266
# ['z']: 0.36070381231671556
# Epoch:  6
# Training Loss:  1.0775216432794414
# Validation Loss:  3.069093153495818
# Accuracy:  0.3710004050222762
# Per sign accuracy:
# ['NaS']: 0.6038659889437168
# ['a']: 0.03571428571428571
# ['b']: 0.8150510204081632
# ['c']: 0.8533475026567482
# ['d']: 0.24162679425837322
# ['e']: 0.002347417840375587
# ['f']: 0.9939903846153846
# ['g']: 0.06091370558375635
# ['h']: 0.19133034379671152
# ['i']: 0.14960629921259844
# ['j']: 0.18125
# ['k']: 0.0
# ['l']: 0.014903129657228018
# ['m']: 0.7674698795180723
# ['n']: 0.8530020703933747
# ['o']: 0.41261061946902655
# ['p']: 0.5515021459227468
# ['q']: 0.13537675606641125
# ['r']: 0.08032596041909197
# ['s']: 0.6689246401354784
# ['t']: 0.3693858845096242
# ['y']: 0.4150717703349282
# ['u']: 0.0
# ['v']: 0.36826347305389223
# ['w']: 0.8197831978319783
# ['x']: 0.04785894206549118
# ['z']: 0.44574780058651026
# Epoch:  7
# Training Loss:  0.941574905609414
# Validation Loss:  2.089024809089785
# Accuracy:  0.489806939381666
# Per sign accuracy:
# ['NaS']: 0.1274811709271695
# ['a']: 0.6282051282051282
# ['b']: 0.764030612244898
# ['c']: 0.7375132837407014
# ['d']: 0.6686602870813397
# ['e']: 0.0011737089201877935
# ['f']: 0.9591346153846154
# ['g']: 0.8152284263959391
# ['h']: 0.1031390134529148
# ['i']: 0.01124859392575928
# ['j']: 0.4475
# ['k']: 0.7694974003466204
# ['l']: 0.22056631892697467
# ['m']: 0.42771084337349397
# ['n']: 0.4658385093167702
# ['o']: 0.04092920353982301
# ['p']: 0.5075107296137339
# ['q']: 0.8863346104725415
# ['r']: 0.17578579743888242
# ['s']: 0.9314140558848434
# ['t']: 0.002749770852428964
# ['y']: 0.7799043062200957
# ['u']: 0.18172983479105928
# ['v']: 0.7350299401197605
# ['w']: 0.8943089430894309
# ['x']: 0.12216624685138538
# ['z']: 0.5351906158357771
# Epoch:  8
# Training Loss:  0.885503707326378
# Validation Loss:  3.0812872549997046
# Accuracy:  0.4424643355384546
# Per sign accuracy:
# ['NaS']: 0.5612733276444181
# ['a']: 0.38461538461538464
# ['b']: 0.7040816326530612
# ['c']: 0.8214665249734325
# ['d']: 0.9832535885167464
# ['e']: 0.0
# ['f']: 0.41346153846153844
# ['g']: 0.6203045685279188
# ['h']: 0.11808669656203288
# ['i']: 0.04611923509561305
# ['j']: 0.0
# ['k']: 0.7677642980935875
# ['l']: 0.3740685543964232
# ['m']: 0.5048192771084338
# ['n']: 0.34368530020703936
# ['o']: 0.06084070796460177
# ['p']: 0.3701716738197425
# ['q']: 0.6947637292464879
# ['r']: 0.9231664726426076
# ['s']: 0.28450465707027944
# ['t']: 0.1695692025664528
# ['y']: 0.7607655502392344
# ['u']: 0.0009718172983479105
# ['v']: 0.5269461077844312
# ['w']: 0.8875338753387534
# ['x']: 0.7544080604534005
# ['z']: 0.35777126099706746
# Epoch:  9
# Training Loss:  0.82859102970912
# Validation Loss:  1.6008382401783168
# Accuracy:  0.56865127582017
# Per sign accuracy:
# ['NaS']: 0.7219604496716506
# ['a']: 0.06684981684981685
# ['b']: 0.9489795918367347
# ['c']: 0.9117959617428267
# ['d']: 0.8708133971291866
# ['e']: 0.0715962441314554
# ['f']: 0.9254807692307693
# ['g']: 0.8751269035532995
# ['h']: 0.5680119581464873
# ['i']: 0.20247469066366705
# ['j']: 0.52375
# ['k']: 0.9792027729636048
# ['l']: 0.4843517138599106
# ['m']: 0.5807228915662651
# ['n']: 0.6521739130434783
# ['o']: 0.2997787610619469
# ['p']: 0.6405579399141631
# ['q']: 0.8710089399744572
# ['r']: 0.640279394644936
# ['s']: 0.6138865368331922
# ['t']: 0.29880843263061413
# ['y']: 0.5586124401913876
# ['u']: 0.06899902818270165
# ['v']: 0.3473053892215569
# ['w']: 0.8306233062330624
# ['x']: 0.756926952141058
# ['z']: 0.6217008797653959
# Epoch:  10
# Training Loss:  0.6846557613867448
# Validation Loss:  1.4804433043390863
# Accuracy:  0.6204941271769947
# Per sign accuracy:
# ['NaS']: 0.6460876340296071
# ['a']: 0.6510989010989011
# ['b']: 0.1096938775510204
# ['c']: 0.9256110520722636
# ['d']: 0.9198564593301436
# ['e']: 0.2335680751173709
# ['f']: 0.9002403846153846
# ['g']: 0.5055837563451777
# ['h']: 0.5321375186846039
# ['i']: 0.21147356580427445
# ['j']: 0.46
# ['k']: 0.9896013864818024
# ['l']: 0.8330849478390462
# ['m']: 0.8722891566265061
# ['n']: 0.7163561076604554
# ['o']: 0.49668141592920356
# ['p']: 0.5214592274678111
# ['q']: 0.8160919540229885
# ['r']: 0.8963911525029103
# ['s']: 0.8526672311600338
# ['t']: 0.31072410632447295
# ['y']: 0.6483253588516746
# ['u']: 0.022351797862001945
# ['v']: 0.718562874251497
# ['w']: 0.8943089430894309
# ['x']: 0.8992443324937027
# ['z']: 0.49560117302052786
# Epoch:  11
# Training Loss:  0.6247286086013901
# Validation Loss:  1.0895636923977527
# Accuracy:  0.6915530354169479
# Per sign accuracy:
# ['NaS']: 0.6746929840834044
# ['a']: 0.7673992673992674
# ['b']: 0.8125
# ['c']: 0.8937300743889479
# ['d']: 0.9629186602870813
# ['e']: 0.27230046948356806
# ['f']: 0.9591346153846154
# ['g']: 0.8812182741116751
# ['h']: 0.5127055306427504
# ['i']: 0.15523059617547807
# ['j']: 0.71
# ['k']: 0.9948006932409013
# ['l']: 0.7347242921013413
# ['m']: 0.9180722891566265
# ['n']: 0.782608695652174
# ['o']: 0.32632743362831856
# ['p']: 0.6469957081545065
# ['q']: 0.6219667943805874
# ['r']: 0.9476135040745053
# ['s']: 0.9695173581710415
# ['t']: 0.49495875343721357
# ['y']: 0.6854066985645934
# ['u']: 0.38095238095238093
# ['v']: 0.5793413173652695
# ['w']: 0.8929539295392954
# ['x']: 0.5503778337531486
# ['z']: 0.5601173020527859
# Epoch:  12
# Training Loss:  0.5519427188234634
# Validation Loss:  1.3837217664984809
# Accuracy:  0.5934476396201791
# Per sign accuracy:
# ['NaS']: 0.6929469817831039
# ['a']: 0.3424908424908425
# ['b']: 0.8826530612244898
# ['c']: 0.8405951115834219
# ['d']: 0.6220095693779905
# ['e']: 0.3380281690140845
# ['f']: 0.8774038461538461
# ['g']: 0.8791878172588833
# ['h']: 0.3393124065769806
# ['i']: 0.265466816647919
# ['j']: 0.66625
# ['k']: 0.9826689774696707
# ['l']: 0.3353204172876304
# ['m']: 0.9144578313253012
# ['n']: 0.7432712215320911
# ['o']: 0.029867256637168143
# ['p']: 0.7982832618025751
# ['q']: 0.6475095785440613
# ['r']: 0.9662398137369034
# ['s']: 0.8966977138018628
# ['t']: 0.5939505041246563
# ['y']: 0.35287081339712917
# ['u']: 0.06705539358600583
# ['v']: 0.24550898203592814
# ['w']: 0.8726287262872628
# ['x']: 0.4168765743073048
# ['z']: 0.5029325513196481
# Epoch:  13
# Training Loss:  0.5173067116814978
# Validation Loss:  1.290246969864591
# Accuracy:  0.6632014760811845
# Per sign accuracy:
# ['NaS']: 0.7113493859681668
# ['a']: 0.5970695970695971
# ['b']: 0.9158163265306123
# ['c']: 0.8650371944739639
# ['d']: 0.972488038277512
# ['e']: 0.4061032863849765
# ['f']: 0.9795673076923077
# ['g']: 0.8761421319796955
# ['h']: 0.2750373692077728
# ['i']: 0.1856017997750281
# ['j']: 0.6325
# ['k']: 0.9844020797227037
# ['l']: 0.353204172876304
# ['m']: 0.8457831325301205
# ['n']: 0.6997929606625258
# ['o']: 0.061946902654867256
# ['p']: 0.7178111587982833
# ['q']: 0.8058748403575989
# ['r']: 0.789289871944121
# ['s']: 0.9153259949195597
# ['t']: 0.40421631530705776
# ['y']: 0.5143540669856459
# ['u']: 0.3965014577259475
# ['v']: 0.7739520958083832
# ['w']: 0.9281842818428184
# ['x']: 0.8438287153652393
# ['z']: 0.6041055718475073
# Epoch:  14
# Training Loss:  0.4659736004382579
# Validation Loss:  1.3051638686228346
# Accuracy:  0.6342198820935151
# Per sign accuracy:
# ['NaS']: 0.697955700664119
# ['a']: 0.5494505494505495
# ['b']: 0.8227040816326531
# ['c']: 0.89798087141339
# ['d']: 0.9569377990430622
# ['e']: 0.4225352112676056
# ['f']: 0.9411057692307693
# ['g']: 0.8365482233502538
# ['h']: 0.31390134529147984
# ['i']: 0.10798650168728909
# ['j']: 0.2675
# ['k']: 0.8388214904679376
# ['l']: 0.5692995529061102
# ['m']: 0.6710843373493975
# ['n']: 0.9140786749482401
# ['o']: 0.23119469026548672
# ['p']: 0.44849785407725323
# ['q']: 0.5964240102171137
# ['r']: 0.8149010477299186
# ['s']: 0.8941574936494496
# ['t']: 0.4225481209899175
# ['y']: 0.5705741626794258
# ['u']: 0.5481049562682215
# ['v']: 0.5029940119760479
# ['w']: 0.8672086720867209
# ['x']: 0.8967254408060453
# ['z']: 0.5425219941348973
# Epoch:  15
# Training Loss:  0.4132551594052805
# Validation Loss:  1.2301564210413791
# Accuracy:  0.6817874983124071
# Per sign accuracy:
# ['NaS']: 0.7316439728416132
# ['a']: 0.76007326007326
# ['b']: 0.8724489795918368
# ['c']: 0.8916046758767269
# ['d']: 0.9485645933014354
# ['e']: 0.4636150234741784
# ['f']: 0.90625
# ['g']: 0.8893401015228426
# ['h']: 0.28550074738415543
# ['i']: 0.11361079865016872
# ['j']: 0.33625
# ['k']: 0.9809358752166378
# ['l']: 0.6363636363636364
# ['m']: 0.8674698795180723
# ['n']: 0.6428571428571429
# ['o']: 0.1747787610619469
# ['p']: 0.6405579399141631
# ['q']: 0.768837803320562
# ['r']: 0.869615832363213
# ['s']: 0.903471634208298
# ['t']: 0.3693858845096242
# ['y']: 0.6985645933014354
# ['u']: 0.5451895043731778
# ['v']: 0.9221556886227545
# ['w']: 0.9376693766937669
# ['x']: 0.809823677581864
# ['z']: 0.6070381231671554
# Epoch:  16
# Training Loss:  0.36821631412198247
# Validation Loss:  1.1548715987988096
# Accuracy:  0.6551910355069529
# Per sign accuracy:
# ['NaS']: 0.6984380217415501
# ['a']: 0.3360805860805861
# ['b']: 0.8775510204081632
# ['c']: 0.8289054197662061
# ['d']: 0.9138755980861244
# ['e']: 0.4624413145539906
# ['f']: 0.9615384615384616
# ['g']: 0.8700507614213198
# ['h']: 0.4499252615844544
# ['i']: 0.23509561304836896
# ['j']: 0.21875
# ['k']: 0.9688041594454073
# ['l']: 0.29210134128166915
# ['m']: 0.7819277108433735
# ['n']: 0.5082815734989649
# ['o']: 0.584070796460177
# ['p']: 0.7607296137339056
# ['q']: 0.7675606641123882
# ['r']: 0.8614668218859138
# ['s']: 0.9491955969517358
# ['t']: 0.3748854262144821
# ['y']: 0.7069377990430622
# ['u']: 0.2925170068027211
# ['v']: 0.8323353293413174
# ['w']: 0.9363143631436315
# ['x']: 0.8841309823677582
# ['z']: 0.5571847507331378
# Epoch:  17
# Training Loss:  0.3143798861190783
# Validation Loss:  1.1075946279011015
# Accuracy:  0.7182395031726745
# Per sign accuracy:
# ['NaS']: 0.7313471598708864
# ['a']: 0.7976190476190477
# ['b']: 0.8979591836734694
# ['c']: 0.8905419766206164
# ['d']: 0.9521531100478469
# ['e']: 0.40375586854460094
# ['f']: 0.9146634615384616
# ['g']: 0.8761421319796955
# ['h']: 0.47085201793721976
# ['i']: 0.33520809898762655
# ['j']: 0.50625
# ['k']: 0.9670710571923743
# ['l']: 0.7049180327868853
# ['m']: 0.891566265060241
# ['n']: 0.7360248447204969
# ['o']: 0.4247787610619469
# ['p']: 0.6802575107296137
# ['q']: 0.7650063856960408
# ['r']: 0.9126891734575088
# ['s']: 0.9178662150719729
# ['t']: 0.3758020164986251
# ['y']: 0.6483253588516746
# ['u']: 0.4198250728862974
# ['v']: 0.8877245508982036
# ['w']: 0.9105691056910569
# ['x']: 0.9105793450881612
# ['z']: 0.624633431085044
# Epoch:  18
# Training Loss:  0.26335177617323574
# Validation Loss:  1.036855850112527
# Accuracy:  0.7185095180234913
# Per sign accuracy:
# ['NaS']: 0.7129818573071643
# ['a']: 0.7161172161172161
# ['b']: 0.8788265306122449
# ['c']: 0.89798087141339
# ['d']: 0.9509569377990431
# ['e']: 0.4284037558685446
# ['f']: 0.9146634615384616
# ['g']: 0.8791878172588833
# ['h']: 0.47832585949177875
# ['i']: 0.3937007874015748
# ['j']: 0.49375
# ['k']: 0.9688041594454073
# ['l']: 0.7257824143070045
# ['m']: 0.8771084337349397
# ['n']: 0.8716356107660456
# ['o']: 0.4081858407079646
# ['p']: 0.6856223175965666
# ['q']: 0.735632183908046
# ['r']: 0.9278230500582072
# ['s']: 0.9661303979678239
# ['t']: 0.384967919340055
# ['y']: 0.65311004784689
# ['u']: 0.5276967930029155
# ['v']: 0.5688622754491018
# ['w']: 0.8834688346883469
# ['x']: 0.8778337531486146
# ['z']: 0.6187683284457478
# Epoch:  19
# Training Loss:  0.23112427544255337
# Validation Loss:  1.0906262509571791
# Accuracy:  0.717384456145088
# Per sign accuracy:
# ['NaS']: 0.728416131784959
# ['a']: 0.6987179487179487
# ['b']: 0.8762755102040817
# ['c']: 0.8894792773645058
# ['d']: 0.9485645933014354
# ['e']: 0.43309859154929575
# ['f']: 0.9014423076923077
# ['g']: 0.8761421319796955
# ['h']: 0.45739910313901344
# ['i']: 0.21822272215973004
# ['j']: 0.55
# ['k']: 0.9584055459272097
# ['l']: 0.7004470938897168
# ['m']: 0.8674698795180723
# ['n']: 0.8219461697722568
# ['o']: 0.536504424778761
# ['p']: 0.674892703862661
# ['q']: 0.7611749680715197
# ['r']: 0.919674039580908
# ['s']: 0.9500423370025403
# ['t']: 0.39688359303391385
# ['y']: 0.7045454545454546
# ['u']: 0.4071914480077745
# ['v']: 0.7994011976047904
# ['w']: 0.8902439024390244
# ['x']: 0.9093198992443325
# ['z']: 0.624633431085044
# Epoch:  20
# Training Loss:  0.21163973700737196
# Validation Loss:  1.0784845520663184
# Accuracy:  0.7222897259349265
# Per sign accuracy:
# ['NaS']: 0.7317181760842949
# ['a']: 0.7335164835164835
# ['b']: 0.8852040816326531
# ['c']: 0.8905419766206164
# ['d']: 0.9497607655502392
# ['e']: 0.4154929577464789
# ['f']: 0.9050480769230769
# ['g']: 0.8771573604060914
# ['h']: 0.4828101644245142
# ['i']: 0.32845894263217096
# ['j']: 0.46625
# ['k']: 0.9601386481802426
# ['l']: 0.7183308494783904
# ['m']: 0.8734939759036144
# ['n']: 0.860248447204969
# ['o']: 0.5243362831858407
# ['p']: 0.6909871244635193
# ['q']: 0.7637292464878672
# ['r']: 0.9185098952270081
# ['s']: 0.9339542760372566
# ['t']: 0.3913840513290559
# ['y']: 0.687799043062201
# ['u']: 0.44703595724003886
# ['v']: 0.7275449101796407
# ['w']: 0.8915989159891599
# ['x']: 0.9219143576826196
# ['z']: 0.624633431085044
# Epoch:  21
# Training Loss:  0.20226455605615382
# Validation Loss:  1.0901604619787928
# Accuracy:  0.7224697358354709
# Per sign accuracy:
# ['NaS']: 0.7310874485215004
# ['a']: 0.7344322344322345
# ['b']: 0.8877551020408163
# ['c']: 0.8969181721572795
# ['d']: 0.9497607655502392
# ['e']: 0.41784037558685444
# ['f']: 0.9050480769230769
# ['g']: 0.8771573604060914
# ['h']: 0.484304932735426
# ['i']: 0.29021372328458944
# ['j']: 0.50125
# ['k']: 0.9462738301559792
# ['l']: 0.7257824143070045
# ['m']: 0.8746987951807229
# ['n']: 0.855072463768116
# ['o']: 0.5309734513274337
# ['p']: 0.6845493562231759
# ['q']: 0.7701149425287356
# ['r']: 0.919674039580908
# ['s']: 0.9271803556308214
# ['t']: 0.39321723189734187
# ['y']: 0.6830143540669856
# ['u']: 0.4421768707482993
# ['v']: 0.7559880239520959
# ['w']: 0.8915989159891599
# ['x']: 0.9156171284634761
# ['z']: 0.624633431085044
# Epoch:  22
# Training Loss:  0.19754536433255052
# Validation Loss:  1.096864987017615
# Accuracy:  0.7216596912830205
# Per sign accuracy:
# ['NaS']: 0.7320149890550217
# ['a']: 0.7362637362637363
# ['b']: 0.8877551020408163
# ['c']: 0.89798087141339
# ['d']: 0.9509569377990431
# ['e']: 0.41901408450704225
# ['f']: 0.9038461538461539
# ['g']: 0.8771573604060914
# ['h']: 0.484304932735426
# ['i']: 0.29021372328458944
# ['j']: 0.4925
# ['k']: 0.9341421143847487
# ['l']: 0.7302533532041728
# ['m']: 0.8759036144578313
# ['n']: 0.8581780538302277
# ['o']: 0.5287610619469026
# ['p']: 0.6834763948497854
# ['q']: 0.7675606641123882
# ['r']: 0.9185098952270081
# ['s']: 0.930567315834039
# ['t']: 0.3950504124656279
# ['y']: 0.6830143540669856
# ['u']: 0.4421768707482993
# ['v']: 0.7470059880239521
# ['w']: 0.8888888888888888
# ['x']: 0.906801007556675
# ['z']: 0.624633431085044
# Epoch:  23
# Training Loss:  0.19537484772151026
# Validation Loss:  1.100578123384888
# Accuracy:  0.7211646640565231
# Per sign accuracy:
# ['NaS']: 0.7318665825696583
# ['a']: 0.7362637362637363
# ['b']: 0.8877551020408163
# ['c']: 0.89798087141339
# ['d']: 0.9509569377990431
# ['e']: 0.41901408450704225
# ['f']: 0.9038461538461539
# ['g']: 0.8771573604060914
# ['h']: 0.484304932735426
# ['i']: 0.29358830146231724
# ['j']: 0.48125
# ['k']: 0.9341421143847487
# ['l']: 0.7332339791356185
# ['m']: 0.8759036144578313
# ['n']: 0.8592132505175983
# ['o']: 0.5298672566371682
# ['p']: 0.6834763948497854
# ['q']: 0.7662835249042146
# ['r']: 0.9185098952270081
# ['s']: 0.9314140558848434
# ['t']: 0.3950504124656279
# ['y']: 0.6830143540669856
# ['u']: 0.4421768707482993
# ['v']: 0.7440119760479041
# ['w']: 0.8861788617886179
# ['x']: 0.9005037783375315
# ['z']: 0.624633431085044
# Epoch:  24
# Training Loss:  0.19470642463311935
# Validation Loss:  1.1022221119511135
# Accuracy:  0.7212546690067954
# Per sign accuracy:
# ['NaS']: 0.7314213631135681
# ['a']: 0.73992673992674
# ['b']: 0.8877551020408163
# ['c']: 0.89798087141339
# ['d']: 0.9509569377990431
# ['e']: 0.41901408450704225
# ['f']: 0.9038461538461539
# ['g']: 0.8771573604060914
# ['h']: 0.484304932735426
# ['i']: 0.29358830146231724
# ['j']: 0.48125
# ['k']: 0.9341421143847487
# ['l']: 0.7332339791356185
# ['m']: 0.8759036144578313
# ['n']: 0.8592132505175983
# ['o']: 0.5298672566371682
# ['p']: 0.6834763948497854
# ['q']: 0.7662835249042146
# ['r']: 0.9185098952270081
# ['s']: 0.9339542760372566
# ['t']: 0.3950504124656279
# ['y']: 0.6830143540669856
# ['u']: 0.4421768707482993
# ['v']: 0.7365269461077845
# ['w']: 0.8861788617886179
# ['x']: 0.9005037783375315
# ['z']: 0.624633431085044

# %% [markdown]
# # Save the Model (for desktop + mobile)

# %%
def save_models(model_output_folder, model_name, desktop_model, mobile_model, normalization_stats, vocab):
    d_today = datetime.now().today().strftime("%Y%m%d%H%M%S")
    model_save_dir = model_output_folder + "/" + d_today
    mkdir(model_save_dir)

    # Save desktop model
    mkdir(model_save_dir + "/desktop")
    save_pickle(normalization_stats, "{}/desktop/stream_{}_norm_stats.pkl".format(model_save_dir, model_name))
    torch.save(desktop_model.state_dict(), "{}/desktop/stream_{}.pt".format(model_save_dir, model_name))

    # Save mobile model
    mkdir(model_save_dir + "/mobile")
    torch.jit.save(mobile_model, "{}/mobile/stream_{}.pt".format(model_save_dir, model_name))
    save_csv(vocab, "{}/mobile/stream_{}_vocab.csv".format(model_save_dir, model_name))
    save_csv(normalization_stats, "{}/mobile/stream_{}_norm_stats.csv".format(model_save_dir, model_name))

# %%
if save:
    dummy_input = torch.rand(1, 1, fps, dims, int(no_of_coords/dims))
    android_model = torch.jit.trace(model.to("cpu"), dummy_input)
    torchscript_optim_android_model = optimize_for_mobile(android_model)
    # Need to move mobile model to CPU before saving or the app crashes
    save_models(model_output_folder, model_name, model, torchscript_optim_android_model.cpu(), normalization_stats, vocab)
