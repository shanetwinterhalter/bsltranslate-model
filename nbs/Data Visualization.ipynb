# %% [markdown]
# # Imports

# %%
# Allow importing items in src folder
import sys

SCRIPT_DIR = "/home/shane/Projects/sign_data"
sys.path.append(SCRIPT_DIR)

# %%
import matplotlib.pyplot as plt

# %%
from src.utilities import convert_to_color_image, plot_key
from src.files import load_pickle

# %% [markdown]
# # Variables

# %%
processed_data_fname = '../saved_coord_data/full_ds_processed_hand_data_mhwl.pkl'

# %%
key = 'b'

# %% [markdown]
# # Read Data

# %%
loaded_data = load_pickle(processed_data_fname)
data = loaded_data[0]
metadata_df = loaded_data[1]

# %%
len(data), len(data['a']), len(data['a'][0])
# Out:
# (27, 97, 19)

# %% [markdown]
# # Plot Image

# %%
test_data = data['a'][0]
plt.imshow(test_data)

# %% [markdown]
# # Convert To Color Image

# %%
data_list = convert_to_color_image(test_data)
plt.imshow(data_list)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Plot all images of a given sign

# %%
plot_key(key, data)
# Out:
# /home/shane/Projects/sign_data/src/utilities.py:60: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
